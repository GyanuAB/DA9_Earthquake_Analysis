# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
# %matplotlib inline

# %%
earth_quake = pd.read_csv("earthquake_data.csv")

# %%
earth_quake.T
# Out:
#                                    0             1             2      \
# Date                          01/02/1965    01/04/1965    01/05/1965
# Time                            13:44:18      11:29:49      18:05:58
# Latitude                          19.246         1.863       -20.579
# Longitude                        145.616       127.352      -173.972
# Type                          Earthquake    Earthquake    Earthquake
# Depth                              131.6            80            20
# Depth Error                          NaN           NaN           NaN
# Depth Seismic Stations               NaN           NaN           NaN
# Magnitude                              6           5.8           6.2
# Magnitude Type                        MW            MW            MW
# Magnitude Error                      NaN           NaN           NaN
# Magnitude Seismic Stations           NaN           NaN           NaN
# Azimuthal Gap                        NaN           NaN           NaN
# Horizontal Distance                  NaN           NaN           NaN
# Horizontal Error                     NaN           NaN           NaN
# Root Mean Square                     NaN           NaN           NaN
# ID                          ISCGEM860706  ISCGEM860737  ISCGEM860762
# Source                            ISCGEM        ISCGEM        ISCGEM
# Location Source                   ISCGEM        ISCGEM        ISCGEM
# Magnitude Source                  ISCGEM        ISCGEM        ISCGEM
# Status                         Automatic     Automatic     Automatic
#
#                                    3             4             5      \
# Date                          01/08/1965    01/09/1965    01/10/1965
# Time                            18:49:43      13:32:50      13:36:32
# Latitude                         -59.076        11.938       -13.405
# Longitude                        -23.557       126.427       166.629
# Type                          Earthquake    Earthquake    Earthquake
# Depth                                 15            15            35
# Depth Error                          NaN           NaN           NaN
# Depth Seismic Stations               NaN           NaN           NaN
# Magnitude                            5.8           5.8           6.7
# Magnitude Type                        MW            MW            MW
# Magnitude Error                      NaN           NaN           NaN
# Magnitude Seismic Stations           NaN           NaN           NaN
# Azimuthal Gap                        NaN           NaN           NaN
# Horizontal Distance                  NaN           NaN           NaN
# Horizontal Error                     NaN           NaN           NaN
# Root Mean Square                     NaN           NaN           NaN
# ID                          ISCGEM860856  ISCGEM860890  ISCGEM860922
# Source                            ISCGEM        ISCGEM        ISCGEM
# Location Source                   ISCGEM        ISCGEM        ISCGEM
# Magnitude Source                  ISCGEM        ISCGEM        ISCGEM
# Status                         Automatic     Automatic     Automatic
#
#                                    6             7                8      \
# Date                          01/12/1965    01/15/1965       01/16/1965
# Time                            13:32:25      23:17:42         11:32:37
# Latitude                          27.357       -13.309          -56.452
# Longitude                         87.867       166.212          -27.043
# Type                          Earthquake    Earthquake       Earthquake
# Depth                                 20            35               95
# Depth Error                          NaN           NaN              NaN
# Depth Seismic Stations               NaN           NaN              NaN
# Magnitude                            5.9             6                6
# Magnitude Type                        MW            MW               MW
# Magnitude Error                      NaN           NaN              NaN
# Magnitude Seismic Stations           NaN           NaN              NaN
# Azimuthal Gap                        NaN           NaN              NaN
# Horizontal Distance                  NaN           NaN              NaN
# Horizontal Error                     NaN           NaN              NaN
# Root Mean Square                     NaN           NaN              NaN
# ID                          ISCGEM861007  ISCGEM861111  ISCGEMSUP861125
# Source                            ISCGEM        ISCGEM        ISCGEMSUP
# Location Source                   ISCGEM        ISCGEM           ISCGEM
# Magnitude Source                  ISCGEM        ISCGEM           ISCGEM
# Status                         Automatic     Automatic        Automatic
#
#                                    9      ...       23402       23403  \
# Date                          01/17/1965  ...  12/24/2016  12/25/2016
# Time                            10:43:17  ...    03:58:55    14:22:27
# Latitude                         -24.563  ...      -5.146    -43.4029
# Longitude                        178.487  ...     153.517    -73.9395
# Type                          Earthquake  ...  Earthquake  Earthquake
# Depth                                565  ...          30          38
# Depth Error                          NaN  ...         1.8         1.9
# Depth Seismic Stations               NaN  ...         NaN         NaN
# Magnitude                            5.8  ...         5.8         7.6
# Magnitude Type                        MW  ...         MWW         MWW
# Magnitude Error                      NaN  ...         NaN         NaN
# Magnitude Seismic Stations           NaN  ...         NaN         NaN
# Azimuthal Gap                        NaN  ...          14          29
# Horizontal Distance                  NaN  ...       1.648       0.351
# Horizontal Error                     NaN  ...           7         6.8
# Root Mean Square                     NaN  ...        0.85         0.8
# ID                          ISCGEM861148  ...  US10007MFP  US10007MN3
# Source                            ISCGEM  ...          US          US
# Location Source                   ISCGEM  ...          US          US
# Magnitude Source                  ISCGEM  ...          US          US
# Status                         Automatic  ...    Reviewed    Reviewed
#
#                                  23404       23405       23406       23407  \
# Date                        12/25/2016  12/27/2016  12/28/2016  12/28/2016
# Time                          14:32:13    23:20:56    08:18:01    08:22:12
# Latitude                       -43.481     45.7192     38.3754     38.3917
# Longitude                     -74.4771      26.523    -118.898    -118.894
# Type                        Earthquake  Earthquake  Earthquake  Earthquake
# Depth                            14.93          97        10.8        12.3
# Depth Error                        3.3         1.8         1.3         1.2
# Depth Seismic Stations             NaN         NaN          34          40
# Magnitude                          5.6         5.6         5.6         5.6
# Magnitude Type                      MB         MWW          ML          ML
# Magnitude Error                  0.067         NaN        0.35        0.32
# Magnitude Seismic Stations          83         NaN          20          18
# Azimuthal Gap                       96          14       35.86       42.47
# Horizontal Distance              0.697       0.465       0.132        0.12
# Horizontal Error                   7.1         5.1         NaN         NaN
# Root Mean Square                  0.52        0.78      0.1988      0.1898
# ID                          US10007MNB  US10007N3R  NN00570709  NN00570710
# Source                              US          US          NN          NN
# Location Source                     US          US          NN          NN
# Magnitude Source                    US          US          NN          NN
# Status                        Reviewed    Reviewed    Reviewed    Reviewed
#
#                                  23408       23409       23410       23411
# Date                        12/28/2016  12/28/2016  12/29/2016  12/30/2016
# Time                          09:13:47    12:38:51    22:30:19    20:08:28
# Latitude                       38.3777     36.9179     -9.0283     37.3973
# Longitude                     -118.896     140.426     118.664      141.41
# Type                        Earthquake  Earthquake  Earthquake  Earthquake
# Depth                              8.8          10          79       11.94
# Depth Error                          2         1.8         1.8         2.2
# Depth Seismic Stations              33         NaN         NaN         NaN
# Magnitude                          5.5         5.9         6.3         5.5
# Magnitude Type                      ML         MWW         MWW          MB
# Magnitude Error                   0.26         NaN         NaN       0.029
# Magnitude Seismic Stations          18         NaN         NaN         428
# Azimuthal Gap                    48.58          91          26          97
# Horizontal Distance              0.129       0.992       3.553       0.681
# Horizontal Error                   NaN         4.8           6         4.5
# Root Mean Square                0.2187        1.52        1.43        0.91
# ID                          NN00570744  US10007NAF  US10007NL0  US10007NTD
# Source                              NN          US          US          US
# Location Source                     NN          US          US          US
# Magnitude Source                    NN          US          US          US
# Status                        Reviewed    Reviewed    Reviewed    Reviewed
#
# [21 rows x 23412 columns]

# %%
earth_quake.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
earth_quake.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
# Here,many null values are present in the different column of dataset.Also, the columns that we are going to use are cleaned i.e no error is present.

# %%
e_data = earth_quake[["Date","Time","Latitude","Longitude","Magnitude","Depth","Type"]]

# %%
# Selection of required columns.

# %%
e_data.T
# Out:
#                 0           1           2           3           4      \
# Date       01/02/1965  01/04/1965  01/05/1965  01/08/1965  01/09/1965
# Time         13:44:18    11:29:49    18:05:58    18:49:43    13:32:50
# Latitude       19.246       1.863     -20.579     -59.076      11.938
# Longitude     145.616     127.352    -173.972     -23.557     126.427
# Magnitude           6         5.8         6.2         5.8         5.8
# Depth           131.6          80          20          15          15
# Type       Earthquake  Earthquake  Earthquake  Earthquake  Earthquake
#
#                 5           6           7           8           9      ...  \
# Date       01/10/1965  01/12/1965  01/15/1965  01/16/1965  01/17/1965  ...
# Time         13:36:32    13:32:25    23:17:42    11:32:37    10:43:17  ...
# Latitude      -13.405      27.357     -13.309     -56.452     -24.563  ...
# Longitude     166.629      87.867     166.212     -27.043     178.487  ...
# Magnitude         6.7         5.9           6           6         5.8  ...
# Depth              35          20          35          95         565  ...
# Type       Earthquake  Earthquake  Earthquake  Earthquake  Earthquake  ...
#
#                 23402       23403       23404       23405       23406  \
# Date       12/24/2016  12/25/2016  12/25/2016  12/27/2016  12/28/2016
# Time         03:58:55    14:22:27    14:32:13    23:20:56    08:18:01
# Latitude       -5.146    -43.4029     -43.481     45.7192     38.3754
# Longitude     153.517    -73.9395    -74.4771      26.523    -118.898
# Magnitude         5.8         7.6         5.6         5.6         5.6
# Depth              30          38       14.93          97        10.8
# Type       Earthquake  Earthquake  Earthquake  Earthquake  Earthquake
#
#                 23407       23408       23409       23410       23411
# Date       12/28/2016  12/28/2016  12/28/2016  12/29/2016  12/30/2016
# Time         08:22:12    09:13:47    12:38:51    22:30:19    20:08:28
# Latitude      38.3917     38.3777     36.9179     -9.0283     37.3973
# Longitude    -118.894    -118.896     140.426     118.664      141.41
# Magnitude         5.6         5.5         5.9         6.3         5.5
# Depth            12.3         8.8          10          79       11.94
# Type       Earthquake  Earthquake  Earthquake  Earthquake  Earthquake
#
# [7 rows x 23412 columns]

# %%
e_data["Date"] = pd.to_datetime(e_data["Date"],utc=True,)
# Out:
# <ipython-input-96-eedf7d6412bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e_data["Date"] = pd.to_datetime(e_data["Date"],utc=True,)

# %%
# Conversion of dates

# %%
e_data['Date']
# Out:
# 0       1965-01-02 00:00:00+00:00
# 1       1965-01-04 00:00:00+00:00
# 2       1965-01-05 00:00:00+00:00
# 3       1965-01-08 00:00:00+00:00
# 4       1965-01-09 00:00:00+00:00
#                    ...
# 23407   2016-12-28 00:00:00+00:00
# 23408   2016-12-28 00:00:00+00:00
# 23409   2016-12-28 00:00:00+00:00
# 23410   2016-12-29 00:00:00+00:00
# 23411   2016-12-30 00:00:00+00:00
# Name: Date, Length: 23412, dtype: datetime64[ns, UTC]

# %%
e_data.pivot_table(index = "Type", values = "Magnitude", aggfunc=len)
# Out:
#                    Magnitude
# Type
# Earthquake           23232.0
# Explosion                4.0
# Nuclear Explosion      175.0
# Rock Burst               1.0

# %%
# From the above table, we have number of occurence of Earthquake,Explosion,Nuclear Explosion and Rock Burst values.

# %%
minimum = e_data["Magnitude"].min()
maximum = e_data["Magnitude"].max()
average = e_data["Magnitude"].mean()

print("Minimum:", minimum)
print("Maximum:",maximum)
print("Mean",average)
# Out:
# Minimum: 5.5
# Maximum: 9.1
# Mean 5.882530753460003

# %%
#  So,the highest magnitude of earthquake is 9.10 and lowest is 5.5.
#  The mean magnitude of earthquake is 5.88

# %%
e_data.groupby('Magnitude').count().T
# Out:
# Magnitude  5.50  5.51  5.52  5.53  5.54  5.55  5.58  5.60  5.62  5.63  ...  \
# Date       4685     1     4     1     1     1     1  3967     1     1  ...
# Time       4685     1     4     1     1     1     1  3967     1     1  ...
# Latitude   4685     1     4     1     1     1     1  3967     1     1  ...
# Longitude  4685     1     4     1     1     1     1  3967     1     1  ...
# Depth      4685     1     4     1     1     1     1  3967     1     1  ...
# Type       4685     1     4     1     1     1     1  3967     1     1  ...
# month      4685     1     4     1     1     1     1  3967     1     1  ...
# Month      4685     1     4     1     1     1     1  3967     1     1  ...
# Year       4685     1     4     1     1     1     1  3967     1     1  ...
#
# Magnitude  7.90  8.00  8.10  8.20  8.30  8.40  8.60  8.70  8.80  9.10
# Date         21    13     7     7     5     2     2     1     1     2
# Time         21    13     7     7     5     2     2     1     1     2
# Latitude     21    13     7     7     5     2     2     1     1     2
# Longitude    21    13     7     7     5     2     2     1     1     2
# Depth        21    13     7     7     5     2     2     1     1     2
# Type         21    13     7     7     5     2     2     1     1     2
# month        21    13     7     7     5     2     2     1     1     2
# Month        21    13     7     7     5     2     2     1     1     2
# Year         21    13     7     7     5     2     2     1     1     2
#
# [9 rows x 64 columns]

# %%
#  The above table shows the number of earthquake occurs at differentt magnitude.

# %%
(n,bins, patches) = plt.hist(e_data["Magnitude"], range=(0,10), bins=10)
plt.xlabel("Earthquake Magnitudes")
plt.ylabel("Number of Occurences")
plt.title("Overview of earthquake magnitudes")

print("Magnitude" +"   "+ "Number of Occurence")
for i in range(5, len(n)):
    print(str(i)+ "-"+str(i+1)+"         " +str(n[i]))
# Out:
# Magnitude   Number of Occurence
# 5-6         16058.0
# 6-7         6616.0
# 7-8         698.0
# 8-9         38.0
# 9-10         2.0

# %%
plt.boxplot(e_data["Magnitude"])
plt.show()

# %%
highly_affected = e_data[e_data["Magnitude"]>=8]

# %%
print(highly_affected.shape)
# Out:
# (40, 8)

# %%
e_data["Month"] = e_data['Date'].dt.month
# Out:
# <ipython-input-106-2bb3d2daf172>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e_data["Month"] = e_data['Date'].dt.month

# %%
month_occurrence = e_data.groupby("Month").groups
print(len(month_occurrence[1]))

month = [i for i in range(1,13)]
occurrence = []

for i in range(len(month)):
    val = month_occurrence[month[i]]
    occurrence.append(len(val))

print(occurrence)
print(sum(occurrence))
# Out:
# 1891
# [1891, 1829, 2114, 1971, 1964, 1824, 1880, 2014, 1985, 1952, 1987, 2001]
# 23412

# %%
# As per the result above, the chances of having earthquakes is more in the month of March,August and Decemmber.

# %%
fig, ax = plt.subplots(figsize = (10,8))
bar_positions = np.arange(12) + 0.5

months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
num_cols = months
bar_heights = occurrence

ax.bar(bar_positions, bar_heights)
tick_positions = np.arange(1,13)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation = 90)
plt.title("Frequency by Month")
plt.xlabel("Months")
plt.ylabel("Frequency")
plt.show()

# %%
e_data["Year"] = e_data['Date'].dt.year
# Out:
# <ipython-input-109-79ca6c5dc953>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e_data["Year"] = e_data['Date'].dt.year

# %%
year_occurrence = e_data.groupby("Year").groups
year = [i for i in range(1965,2017)]
occurrence = []

for i in range(len(year)):
    val = year_occurrence[year[i]]
    occurrence.append(len(val))

maximum = max(occurrence)
minimum = min(occurrence)
print("Maximum",maximum)
print("Minimum",minimum)
# Out:
# Maximum 713
# Minimum 234

# %%
# The maximum Earthquake that occurs in a year is 713 and minimum 234.

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(year,occurrence)
plt.xticks(rotation = 90)
plt.xlabel("Year")
plt.ylabel("Number of Occurrence")
plt.title("Frequency of Earthquakes by Year")
plt.xlim(1965,2017)
plt.show()

# %%
plt.scatter(e_data["Magnitude"],e_data["Depth"])

# %%
# The above graph shows the relationship between Depth and the magnitude.

# %%
supermoon_date = ["2016-11-14","2016-11-16","2016-11-15"] 
#( one day before and after)
supermoon = e_data[e_data['Date'].isin(supermoon_date)]

supermoon
# Out:
#                            Date                 Time  Latitude  Longitude  \
# 23336 2016-11-14 00:00:00+00:00  2020-10-14 00:34:23  -42.6058   173.2543
# 23337 2016-11-14 00:00:00+00:00  2020-10-14 02:12:17   51.0735   178.8402
# 23338 2016-11-14 00:00:00+00:00  2020-10-14 06:47:52  -42.3335   173.9064
# 23339 2016-11-14 00:00:00+00:00  2020-10-14 07:21:05  -41.7598   174.2992
# 23340 2016-11-15 00:00:00+00:00  2020-10-14 01:34:44  -41.7875   174.3064
# 23341 2016-11-16 00:00:00+00:00  2020-10-14 00:30:30  -20.2391  -173.0161
# 23342 2016-11-16 00:00:00+00:00  2020-10-14 15:10:11   -9.0027   113.2445
#
#        Magnitude  Depth        Type  month  Month  Year
# 23336        6.5   9.00  Earthquake     11     11  2016
# 23337        5.6  34.26  Earthquake     11     11  2016
# 23338        5.7  12.00  Earthquake     11     11  2016
# 23339        5.5  17.21  Earthquake     11     11  2016
# 23340        5.5  10.00  Earthquake     11     11  2016
# 23341        5.8  20.00  Earthquake     11     11  2016
# 23342        5.7  85.00  Earthquake     11     11  2016

# %%
# The above table shows the occurence of earthquake on the FullMoon with their magnitude.

# %%
#  So, this is all about Earthquake analysis.

#  AKHIL BHALL
